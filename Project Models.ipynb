# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
import xgboost as xgb
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressorand
from sklearn.tree import DecisionTreeRegressor
from scipy.stats import boxcox
warnings.filterwarnings('ignore')

# %% [markdown]
# # Introduction

# %% [markdown]
# In this project how different models perform on certain datasets and how exploratory data analysis affects the given models will be demonstrated. Boston housing dataset from kaggle (https://www.kaggle.com/c/house-prices-advanced-regression-techniques) will be used for linear regression models, the "hello world" dataset of machine learning: titanic dataset will be used for binary classification(https://www.kaggle.com/c/titanic/data), and Fashion MNIST (https://www.kaggle.com/zalando-research/fashionmnist) dataset will be used for multiclass classification. (tensorflow.keras.datasets library will be used for importing the fashion MNIST dataset)

# %% [markdown]
# # Datasets

# %% [markdown]
#  Both time spent and accuracy of algorithms will be inspected for all datasets. (Only some models can work with raw(unfilled) dataset.)

# %% [markdown]
# Raw:
#
#     Datasets will be imported from original sources

# %% [markdown]
# Filled:
#
#     Raw datasets will be checked for missing(NaN) values, and missing values will be filled by various methods.(mean, median, enterpolation)

# %% [markdown]
# Transformation:
#
#     Filled raw features will be transformed with Box-cox transformation.(https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.boxcox.html)

# %% [markdown]
# ## Raw

# %%
from tensorflow.keras.datasets import fashion_mnist

fashion_mnist = fashion_mnist
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-0303511a55ca> in <module>
#       1 from tensorflow.keras.datasets import fashion_mnist
#       2
# ----> 3 fashion_mnist = fashion_mnist()
#
# TypeError: 'module' object is not callable

# %% [markdown]
# ## Filled

# %% [markdown]
# ## Transformation (on Filled)

# %% [markdown]
# ## Normalized (on Transformed)

# %% [markdown]
# ## General Properties of Datasets

# %% [markdown]
# # Models

# %% [markdown]
# All models will be defined in this section. As same models will be used in multiple times, definitions may help save time for us. Check definitions if you have detailed informations about how algorithms used(and with what hyperparameters).

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ## Binary Classification

# %% [markdown]
# ## Multi-Class Classification

# %% [markdown]
# # Models on Datasets

# %% [markdown]
# ## Linear Regression (on House Prices dataset)

# %% [markdown]
# ## Binary Classification (on Titanic dataset)

# %% [markdown]
# ## Multi-Class Classification (on Fashion MNIST)

# %% [markdown]
# # Comparison of Models

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ## Binary Classification

# %% [markdown]
# ## Multi-Class Classification
